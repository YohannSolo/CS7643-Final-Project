# %% [markdown]
# ## Install and Import Packages

# %%
from transformers import AutoTokenizer, PreTrainedTokenizer
from typing import Dict
from predibase import Predibase, FinetuningConfig, DeploymentConfig
from datasets import load_dataset

import pandas as pd
import numpy as np

import json
import pprint

# %% [markdown]
# ## Login To Predibase

# %%
# Initialize the Predibase Client
pb = Predibase(api_token="pb_aegFsnR9UcSctYBOrXe9Sw")
# Out:
# Connected to Predibase as User(id=251e2a3c-ab61-4c2a-a98e-97f578aadfed, username=ckniffin6@gatech.edu)

# %%
# Create an adapter repository
repo = pb.repos.create(name="alpha_sweep", description="sweeping the alpha param", exists_ok=True)

# %%
# Start a fine-tuning job with custom parameters, blocks until training is finished
adapter = pb.adapters.create(
    config=FinetuningConfig(
        base_model="mistral-7b",
        epochs=4, # default: 3
        rank=8, # default: 16
        learning_rate=0.0002, # default: 0.0002
        alpha=8
    ),
    dataset="new_fin_dataset",
    repo=repo,
    description="alpah_8"
)
# Out:
# Successfully requested finetuning of mistral-7b as `alpha_sweep/4`. (Job UUID: 3e0d11bd-d377-4053-9bad-2910fd5eadac).
#
# Watching progress of finetuning job 3e0d11bd-d377-4053-9bad-2910fd5eadac. This call will block until the job has finished. Canceling or terminating this call will NOT cancel or terminate the job itself.
#
#
#
# Job is queued for execution. Time in queue: 0:00:32
# KeyboardInterrupt
